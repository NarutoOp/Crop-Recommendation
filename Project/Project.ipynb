# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LinearRegression
from sklearn.multioutput import MultiOutputRegressor
from sklearn.ensemble import RandomForestRegressor

# %%
#i=input("Enter the location")
data=pd.read_csv("cropdata.csv",index_col=0)
s=data.iloc[:,3:]
s2 = pd.DataFrame({'Crop':s.idxmax(axis=1)})
data.drop(data.iloc[:,3:],inplace = True, axis = 1)
data1=data.merge(s2,right_index=True, left_index=True) 
#data1.set_index("State", inplace = True)
# data1=data0.loc[i]
# data2=data1.drop_duplicates(['Month'])
data1
# Out:
#     Soil     Month State    Crop
# 0     AL   January   APT    Rice
# 1     AL   January   ASM    Rice
# 2     AL   January   BHR    Rice
# 3     AL   January   GJT    Rice
# 4     AL   January   HYA    Rice
# ..   ...       ...   ...     ...
# 790   DT  November   MDP  Barley
# 791   DT  November   PJB  Barley
# 792   DT  November   RJN  Barley
# 793   DT  November   UTP  Barley
# 794   DT  November   UKD  Barley
#
# [795 rows x 4 columns]

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
x1=data1["State"]
encoded_value = le.fit_transform(x1)
print(encoded_value)
# Out:
# [ 0  1  2  4  6  5  9  8 10 11 12 13 15 17 18  3  7 16  0  9 11 15 17 16
#   0  9 11 15 17 16  0  4  6  9 10 11 12 13 14 15 17 16  0  1  2  4  6  5
#   9  8 10 11 12 13 14 15 17 18  3  7 16  0  1  2  4  6  5  9  8 10 11 12
#  13 14 15 17 18  3  7 16  0  1  2  4  6  5  9  8 10 11 12 13 14 15 17 18
#   3  7 16  0  1  2  4  6  5  9  8 10 11 12 13 14 15 17 18  3  7 16  0  1
#   2  4  6  5  9  8 10 11 12 13 15 17 18  3  7 16  2  4  6  5 10 13 14 17
#  18  7 16  2  4  6  5 10 13 14 17 18  7 16  0  1  2  4  6  5  9  8 10 11
#  12 13 14 15 17 18  3  7 16  0  1  2  4  6  5  9  8 10 11 12 13 14 15 17
#  18  3  7 16  0  4  6  9 10 11 14 15 17 16  0  9 11 15 17 16  0  9 11 15
#  17 16  0  1  2  4  6  5  9  8 10 11 12 13 14 15 17 18  3  7 16  0  1  2
#   4  6  5  9  8 10 11 12 13 14 15 17 18  3  7 16  0  1  2  4  6  5  9  8
#  10 11 12 13 14 15 17 18  3  7 16  0  1  2  4  6  5  9  8 10 11 12 13 14
#  15 17 18  3  7 16  0  1  2  4  6  5  9  8 10 11 12 13 14 15 17 18  3  7
#  16  0  2  4  6  5  9 10 11 12 13 14 15 17 18  7 16  0  2  4  6  5  9 10
#  11 12 13 14 15 17 18  7 16  0  1  2  4  6  5  9  8 10 11 12 13 14 15 17
#  18  3  7 16  0  1  2  4  6  5  9  8 10 11 12 13 14 15 17 18  3  7 16  0
#   4  6  9 10 11 14 15 17 16  0  2  5  9 10 11 12 13 14 15 17  7 16  0  2
#   4  6  5  9 10 11 12 13 14 15 17  7 16  0  1  2  4  6  5  9  8 10 11 12
#  13 14 15 17 18  3  7 16  0  1  2  4  6  5  9  8 10 11 12 13 14 15 17 18
#   3  7 16  0  1  2  4  6  5  9  8 10 11 12 13 14 15 17 18  3  7 16  0  1
#   2  4  6  5  9  8 10 11 12 13 14 15 17 18  3  7 16  0  1  2  4  6  5  9
#   8 10 11 12 13 14 15 17 18  3  7 16  0  2  4  6  5  9 10 11 12 13 14 15
#  17 18  7 16  0  2  4  6  5  9 10 11 12 13 14 15 17 18  7 16  0  1  2  4
#   6  5  9  8 10 11 12 13 14 15 17 18  3  7 16  1  2  5  9  8 12 15 18 16
#   1  2  5  9  8 12 15 18 16  1  2  5  9  8 12 15 18 16  1  2  5  9  8 12
#  15 18 16  1  2  5  9  8 12 15 18 16  0  9  8 15  0  9  8 15  0  9  8 15
#   0  9  8 15  0  9  8 15  0  9  8 15  0  9  8 15  1  2  5  9  8 12 15 18
#  16  0  1  2  5  9  8 11 12 15 18 16  0  1  2  5  9  8 11 12 15 18 16  1
#   2  5  9  8 12 15 18 16  1  2  5  9  8 12 15 18 16  0  9  8 15  0  9  8
#  15  0  9  8 15  0  9  8 15  0  9  8 15  0  9  8 15  0  9  8 15  0  4  6
#   9 10 11 14 15 17  0  4  6  9 10 11 14 15 17  0  4  6  9 10 11 14 15 17
#   0  4  6  9 10 11 14 15 17  0  4  6  9 10 11 14 15 17  0  4  6  9 10 11
#  14 15 17  2  6  5 10 13 14 17 16  2  6  5 10 13 14 17 16  2  6  5 10 13
#  14 17 16]

# %%
import numpy as np
ini_array1 = np.array(encoded_value)

result = ini_array1.flatten()
b={'State_c':result}
data2=data1.merge(pd.DataFrame(b),right_index=True, left_index=True)
data2.head()
# Out:
#   Soil    Month State  Crop  State_c
# 0   AL  January   APT  Rice        0
# 1   AL  January   ASM  Rice        1
# 2   AL  January   BHR  Rice        2
# 3   AL  January   GJT  Rice        4
# 4   AL  January   HYA  Rice        6

# %%
X = data2[['State_c']].values
Y = data2[['Crop']].values

# %%
# clf = DecisionTreeClassifier(random_state=42)
# print(cross_val_score(clf, X, Y, cv=10))
# Out:
# [0.175      0.1875     0.1875     0.25       0.1        0.11392405
#  0.13924051 0.25316456 0.30379747 0.01265823]

# %%
X_train,X_test,Y_train,Y_test =train_test_split(X,Y,test_size =0.20,random_state=0)

regressor=LinearRegression()
regressor.fit(X_train,Y_train)
# regressor.score(X_train,Y_train)*100
Y_pred=regressor.predict(X_test)
result=pd.DataFrame({'Actual':Y_test,'Predicted':Y_pred})
# print(result)
# plt.plot(X_test,Y_test)
# plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-b2ddb70de0f1> in <module>
#       2
#       3 regressor=LinearRegression()
# ----> 4 regressor.fit(X_train,Y_train)
#       5 # regressor.score(X_train,Y_train)*100
#       6 Y_pred=regressor.predict(X_test)
#
# c:\users\zinga\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\linear_model\base.py in fit(self, X, y, sample_weight)
#     461         n_jobs_ = self.n_jobs
#     462         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 463                          y_numeric=True, multi_output=True)
#     464
#     465         if sample_weight is not None and np.atleast_1d(sample_weight).ndim > 1:
#
# c:\users\zinga\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     725         _assert_all_finite(y)
#     726     if y_numeric and y.dtype.kind == 'O':
# --> 727         y = y.astype(np.float64)
#     728
#     729     check_consistent_length(X, y)
#
# ValueError: could not convert string to float: 'Rice'

# %%
max_depth = 30
regr_multirf = MultiOutputRegressor(RandomForestRegressor(n_estimators=100,
                                                          max_depth=max_depth,
                                                          random_state=0))
regr_multirf.fit(X_train, Y_train)

regr_rf = RandomForestRegressor(n_estimators=100, max_depth=max_depth,
                                random_state=2)
regr_rf.fit(X_train, Y_train)

# Predict on new data
y_multirf = regr_multirf.predict(X_test)
y_rf = regr_rf.predict(X_test)
y_rf
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-94b6d330086e> in <module>
#       3                                                           max_depth=max_depth,
#       4                                                           random_state=0))
# ----> 5 regr_multirf.fit(X_train, Y_train)
#       6
#       7 regr_rf = RandomForestRegressor(n_estimators=100, max_depth=max_depth,
#
# c:\users\zinga\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\multioutput.py in fit(self, X, y, sample_weight)
#     167             delayed(_fit_estimator)(
#     168                 self.estimator, X, y[:, i], sample_weight)
# --> 169             for i in range(y.shape[1]))
#     170         return self
#     171
#
# c:\users\zinga\appdata\local\programs\python\python37-32\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#     919             # remaining jobs.
#     920             self._iterating = False
# --> 921             if self.dispatch_one_batch(iterator):
#     922                 self._iterating = self._original_iterator is not None
#     923
#
# c:\users\zinga\appdata\local\programs\python\python37-32\lib\site-packages\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     757                 return False
#     758             else:
# --> 759                 self._dispatch(tasks)
#     760                 return True
#     761
#
# c:\users\zinga\appdata\local\programs\python\python37-32\lib\site-packages\joblib\parallel.py in _dispatch(self, batch)
#     714         with self._lock:
#     715             job_idx = len(self._jobs)
# --> 716             job = self._backend.apply_async(batch, callback=cb)
#     717             # A job can complete so quickly than its callback is
#     718             # called before we get here, causing self._jobs to
#
# c:\users\zinga\appdata\local\programs\python\python37-32\lib\site-packages\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     180     def apply_async(self, func, callback=None):
#     181         """Schedule a func to be run"""
# --> 182         result = ImmediateResult(func)
#     183         if callback:
#     184             callback(result)
#
# c:\users\zinga\appdata\local\programs\python\python37-32\lib\site-packages\joblib\_parallel_backends.py in __init__(self, batch)
#     547         # Don't delay the application, to avoid keeping the input
#     548         # arguments in memory
# --> 549         self.results = batch()
#     550
#     551     def get(self):
#
# c:\users\zinga\appdata\local\programs\python\python37-32\lib\site-packages\joblib\parallel.py in __call__(self)
#     223         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     224             return [func(*args, **kwargs)
# --> 225                     for func, args, kwargs in self.items]
#     226
#     227     def __len__(self):
#
# c:\users\zinga\appdata\local\programs\python\python37-32\lib\site-packages\joblib\parallel.py in <listcomp>(.0)
#     223         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     224             return [func(*args, **kwargs)
# --> 225                     for func, args, kwargs in self.items]
#     226
#     227     def __len__(self):
#
# c:\users\zinga\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\multioutput.py in _fit_estimator(estimator, X, y, sample_weight)
#      37         estimator.fit(X, y, sample_weight=sample_weight)
#      38     else:
# ---> 39         estimator.fit(X, y)
#      40     return estimator
#      41
#
# c:\users\zinga\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\ensemble\forest.py in fit(self, X, y, sample_weight)
#     276
#     277         if getattr(y, "dtype", None) != DOUBLE or not y.flags.contiguous:
# --> 278             y = np.ascontiguousarray(y, dtype=DOUBLE)
#     279
#     280         if expanded_class_weight is not None:
#
# c:\users\zinga\appdata\local\programs\python\python37-32\lib\site-packages\numpy\core\numeric.py in ascontiguousarray(a, dtype)
#     630
#     631     """
# --> 632     return array(a, dtype, copy=False, order='C', ndmin=1)
#     633
#     634
#
# ValueError: could not convert string to float: 'Rice'
